# %% [markdown]
# # Analysis of  Zomato Bangalore Restaurant dataset

# %% [markdown]
# Loading the dataset: Load the data and import the libraries.
#
# Data Cleaning:
# Deleting redundant columns.
#
# Renaming the columns.
#
# Dropping duplicates.
#
# Cleaning individual columns.
#
# Remove the NaN values from the dataset
#
# Some Transformations
#
# Data Visualization

# %%
#importing Required library 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#importing plotly Library
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf
py.offline.init_notebook_mode(connected=True) #Turning on notebook mode 
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.0.min"</script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.0.min"</script>

# %%
# importing the dataset
# Using encoding parameter to handle non-UTF-8 characters
df = pd.read_csv(r"zomato.csv") 
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari
# 3          Buffet    Banashankari
# 4          Buffet    Banashankari

# %%
df.shape
# Out:
# (51717, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
#  13  reviews_list                 51717 non-null  object
#  14  menu_item                    51717 non-null  object
#  15  listed_in(type)              51717 non-null  object
#  16  listed_in(city)              51717 non-null  object
# dtypes: int64(1), object(16)
# memory usage: 6.7+ MB

# %%
del df["url"]
del df["address"]
del df["phone"]

# %%
# Duplicates values
df.duplicated().sum()
# Out:
# np.int64(63)

# %%
df.drop_duplicates(inplace=True)

# %%
#checking the NaN values
df.isnull().sum()
# Out:
# name                               0
# online_order                       0
# book_table                         0
# rate                            7760
# votes                              0
# location                          21
# rest_type                        227
# dish_liked                     28027
# cuisines                          45
# approx_cost(for two people)      345
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
del df["dish_liked"]

# %%
df.dropna(how='any',inplace=True)

# %%
#checking the NaN values
df.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# location                       0
# rest_type                      0
# cuisines                       0
# approx_cost(for two people)    0
# reviews_list                   0
# menu_item                      0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
#Reading Column Names
df.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes', 'location',
#        'rest_type', 'cuisines', 'approx_cost(for two people)', 'reviews_list',
#        'menu_item', 'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
#Changing the column names
df = df.rename(columns={'approx_cost(for two people)':'cost','listed_in(type)':'type',
                                  'listed_in(city)':'city'})
df.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes', 'location',
#        'rest_type', 'cuisines', 'cost', 'reviews_list', 'menu_item', 'type',
#        'city'],
#       dtype='object')

# %%
df.head()
# Out:
#                     name online_order book_table   rate  votes      location  \
# 0                  Jalsa          Yes        Yes  4.1/5    775  Banashankari
# 1         Spice Elephant          Yes         No  4.1/5    787  Banashankari
# 2        San Churro Cafe          Yes         No  3.8/5    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88  Banashankari
# 4          Grand Village           No         No  3.8/5    166  Basavanagudi
#
#              rest_type                        cuisines cost  \
# 0        Casual Dining  North Indian, Mughlai, Chinese  800
# 1        Casual Dining     Chinese, North Indian, Thai  800
# 2  Cafe, Casual Dining          Cafe, Mexican, Italian  800
# 3          Quick Bites      South Indian, North Indian  300
# 4        Casual Dining        North Indian, Rajasthani  600
#
#                                         reviews_list menu_item    type  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []  Buffet
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []  Buffet
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []  Buffet
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []  Buffet
#
#            city
# 0  Banashankari
# 1  Banashankari
# 2  Banashankari
# 3  Banashankari
# 4  Banashankari

# %%
df.cost.unique()
# Out:
# array(['800', '300', '600', '700', '550', '500', '450', '650', '400',
#        '900', '200', '750', '150', '850', '100', '1,200', '350', '250',
#        '950', '1,000', '1,500', '1,300', '199', '80', '1,100', '160',
#        '1,600', '230', '130', '1,700', '1,400', '1,350', '2,200', '2,000',
#        '1,800', '1,900', '180', '330', '2,500', '2,100', '3,000', '2,800',
#        '3,400', '50', '40', '1,250', '3,500', '4,000', '2,400', '2,600',
#        '1,450', '70', '3,200', '560', '240', '360', '6,000', '1,050',
#        '2,300', '4,100', '120', '5,000', '3,700', '1,650', '2,700',
#        '4,500'], dtype=object)

# %%
print(type(df['cost'])) # = df['cost'].astype(float)
# Out:
# <class 'pandas.core.series.Series'>

# %%
#Some Transformations
df['cost'] = df['cost'].astype(str) #Changing the cost to string
df['cost'] = df['cost'].apply(lambda x: x.replace(',','')) #Using lambda function to replace ',' from cost
df['cost'] = df['cost'].astype(float) # Changing the cost to Float
df.info() # looking at the dataset information after transformation
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43486 entries, 0 to 51716
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          43486 non-null  object
#  1   online_order  43486 non-null  object
#  2   book_table    43486 non-null  object
#  3   rate          43486 non-null  object
#  4   votes         43486 non-null  int64
#  5   location      43486 non-null  object
#  6   rest_type     43486 non-null  object
#  7   cuisines      43486 non-null  object
#  8   cost          43486 non-null  float64
#  9   reviews_list  43486 non-null  object
#  10  menu_item     43486 non-null  object
#  11  type          43486 non-null  object
#  12  city          43486 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 4.6+ MB

# %%
print(type(df['cost']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
#Removing '/5' from Rates
df = df.loc[df.rate !='NEW'] #Removed rows which were having "new"
df = df.loc[df.rate !='-'].reset_index(drop=True) #Removed rows which were having "-"
remove_slash = lambda x: x.replace('/5', '') if type(x) == str else x #Function 
df.rate = df.rate.apply(remove_slash).str.strip().astype(float)#apply function to col
df['rate'].head() # looking at the dataset after transformation
# Out:
# 0    4.1
# 1    4.1
# 2    3.8
# 3    3.7
# 4    3.8
# Name: rate, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41226 entries, 0 to 41225
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          41226 non-null  object
#  1   online_order  41226 non-null  object
#  2   book_table    41226 non-null  object
#  3   rate          41226 non-null  float64
#  4   votes         41226 non-null  int64
#  5   location      41226 non-null  object
#  6   rest_type     41226 non-null  object
#  7   cuisines      41226 non-null  object
#  8   cost          41226 non-null  float64
#  9   reviews_list  41226 non-null  object
#  10  menu_item     41226 non-null  object
#  11  type          41226 non-null  object
#  12  city          41226 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 4.1+ MB

# %%
df['cost'].mean()
# Out:
# np.float64(603.9612380536555)

# %%
df.online_order.value_counts().plot.pie(fontsize = 18, autopct = '%.2f')
plt.show()

# %%
df.book_table.value_counts().plot.pie(fontsize = 18, autopct = '%.2f')
plt.show()

# %% [markdown]
# # Largest Food Chain in Bangalore

# %%
df.name.value_counts().head(10).plot(kind="bar")
plt.show()

# %% [markdown]
# # Most Popular Restaurant types

# %%
#df.rest_type.value_counts().head(10).iplot(kind="bar")

import plotly.express as px

# Prepare the data
top_rest_types = df['rest_type'].value_counts().head(10).reset_index()
top_rest_types.columns = ['rest_type', 'count']

# Plot
fig = px.bar(top_rest_types, x='rest_type', y='count', title='Top 10 Restaurant Types')
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="bacf2bbe-d58e-4555-b162-9eecd4e72f27" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bacf2bbe-d58e-4555-b162-9eecd4e72f27")) {                    Plotly.newPlot(                        "bacf2bbe-d58e-4555-b162-9eecd4e72f27",                        [{"hovertemplate":"rest_type=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Quick Bites","Casual Dining","Cafe","Dessert Parlor","Delivery","Takeaway, Delivery","Casual Dining, Bar","Bakery","Bar","Beverage Shop"],"xaxis":"x","y":{"dtype":"i2","bdata":"KjaFJSgNOgeCBv4ERATAAoACfgI="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"s ...

# %%
df.describe()
# Out:
#                rate         votes          cost
# count  41226.000000  41226.000000  41226.000000
# mean       3.702091    352.863217    603.961238
# std        0.440063    884.509575    464.985064
# min        1.800000      0.000000     40.000000
# 25%        3.400000     21.000000    300.000000
# 50%        3.700000     73.500000    500.000000
# 75%        4.000000    278.000000    750.000000
# max        4.900000  16832.000000   6000.000000

# %%
num_cols = ['cost','rate','votes','cost']
i=0
while i < 4:
    fig = plt.figure(figsize=[13,3])
    #ax1 = fig.add_subplot(121)
    #ax2 = fig.add_subplot(122)
    
    #ax1.title.set_text(num_cols[i])
    plt.subplot(1,2,1)
    sns.boxplot(x=num_cols[i], data=df)
    i += 1
    
    #ax2.title.set_text(num_cols[i])
    plt.subplot(1,2,2)
    sns.boxplot(x=num_cols[i], data=df)
    i += 1
    
    plt.show()

# %% [markdown]
# # Expensive Restaurants in Bangalore

# %%
#pd.set_option("display.max_rows", None, "display.max_columns", None)
df[df.cost>3000].sort_values(ascending=False,by="cost")
# Out:
#                                                     name online_order  \
# 15114             Le Cirque Signature - The Leela Palace           No
# 36363             Le Cirque Signature - The Leela Palace           No
# 32048                         Royal Afghan - ITC Windsor           No
# 33105                             Malties - Radisson Blu           No
# 33520                             Malties - Radisson Blu           No
# ...                                                  ...          ...
# 33562                      The Market - The Ritz-Carlton           No
# 31079  b CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃ...           No
# 3985                       The Market - The Ritz-Carlton           No
# 10421                     Blue Ginger - The Taj West End           No
# 30707                     Blue Ginger - The Taj West End           No
#
#       book_table  rate  votes          location         rest_type  \
# 15114        Yes   4.3    126  Old Airport Road       Fine Dining
# 36363        Yes   4.3    128  Old Airport Road       Fine Dining
# 32048        Yes   4.3    413       Sankey Road       Fine Dining
# 33105         No   4.3     53      Marathahalli            Lounge
# 33520         No   4.3     53      Marathahalli            Lounge
# ...          ...   ...    ...               ...               ...
# 33562        Yes   4.3    620    Residency Road       Fine Dining
# 31079        Yes   4.3    429     Vasanth Nagar  Fine Dining, Bar
# 3985         Yes   4.3    622    Residency Road       Fine Dining
# 10421        Yes   4.4    514  Race Course Road       Fine Dining
# 30707        Yes   4.4    516  Race Course Road       Fine Dining
#
#                                        cuisines    cost  \
# 15114                           French, Italian  6000.0
# 36363                           French, Italian  6000.0
# 32048                     North Indian, Mughlai  5000.0
# 33105                    Continental, Fast Food  4500.0
# 33520                    Continental, Fast Food  4500.0
# ...                                         ...     ...
# 33562              North Indian, European, Thai  3400.0
# 31079  North Indian, Italian, Chinese, Japanese  3400.0
# 3985               North Indian, European, Thai  3400.0
# 10421                                Vietnamese  3200.0
# 30707                                Vietnamese  3200.0
#
#                                             reviews_list menu_item  \
# 15114  [('Rated 5.0', 'RATED\n  Awesome would be an u...        []
# 36363  [('Rated 5.0', 'RATED\n  Awesome would be an u...        []
# 32048  [('Rated 5.0', 'RATED\n  It is just Bukhara wi...        []
# 33105  [('Rated 3.0', "RATED\n  We had visited this p...        []
# 33520  [('Rated 3.0', "RATED\n  We had visited this p...        []
# ...                                                  ...       ...
# 33562  [('Rated 3.0', 'RATED\n  Went there for buffet...        []
# 31079  [('Rated 2.0', "RATED\n  I was here last Sunda...        []
# 3985   [('Rated 4.0', 'RATED\n  Had breakfast at the ...        []
# 10421  [('Rated 5.0', 'RATED\n  Such an elegant place...        []
# 30707  [('Rated 5.0', 'RATED\n  Such an elegant place...        []
#
#                      type              city
# 15114            Dine-out       Indiranagar
# 36363            Dine-out  Old Airport Road
# 32048            Dine-out      Malleshwaram
# 33105            Dine-out      Marathahalli
# 33520  Drinks & nightlife      Marathahalli
# ...                   ...               ...
# 33562              Buffet           MG Road
# 31079            Dine-out      Lavelle Road
# 3985               Buffet      Brigade Road
# 10421            Dine-out     Church Street
# 30707            Dine-out      Lavelle Road
#
# [79 rows x 13 columns]

# %% [markdown]
# Expensive Restaurants Don't take online orders but table booking is Available.
#
# Majority of Expensive Restaurants are having ratings above 4.

# %%
df[df.cost>3000].sort_values(ascending=False,by="cost")
# Out:
#                                                     name online_order  \
# 15114             Le Cirque Signature - The Leela Palace           No
# 36363             Le Cirque Signature - The Leela Palace           No
# 32048                         Royal Afghan - ITC Windsor           No
# 33105                             Malties - Radisson Blu           No
# 33520                             Malties - Radisson Blu           No
# ...                                                  ...          ...
# 33562                      The Market - The Ritz-Carlton           No
# 31079  b CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃ...           No
# 3985                       The Market - The Ritz-Carlton           No
# 10421                     Blue Ginger - The Taj West End           No
# 30707                     Blue Ginger - The Taj West End           No
#
#       book_table  rate  votes          location         rest_type  \
# 15114        Yes   4.3    126  Old Airport Road       Fine Dining
# 36363        Yes   4.3    128  Old Airport Road       Fine Dining
# 32048        Yes   4.3    413       Sankey Road       Fine Dining
# 33105         No   4.3     53      Marathahalli            Lounge
# 33520         No   4.3     53      Marathahalli            Lounge
# ...          ...   ...    ...               ...               ...
# 33562        Yes   4.3    620    Residency Road       Fine Dining
# 31079        Yes   4.3    429     Vasanth Nagar  Fine Dining, Bar
# 3985         Yes   4.3    622    Residency Road       Fine Dining
# 10421        Yes   4.4    514  Race Course Road       Fine Dining
# 30707        Yes   4.4    516  Race Course Road       Fine Dining
#
#                                        cuisines    cost  \
# 15114                           French, Italian  6000.0
# 36363                           French, Italian  6000.0
# 32048                     North Indian, Mughlai  5000.0
# 33105                    Continental, Fast Food  4500.0
# 33520                    Continental, Fast Food  4500.0
# ...                                         ...     ...
# 33562              North Indian, European, Thai  3400.0
# 31079  North Indian, Italian, Chinese, Japanese  3400.0
# 3985               North Indian, European, Thai  3400.0
# 10421                                Vietnamese  3200.0
# 30707                                Vietnamese  3200.0
#
#                                             reviews_list menu_item  \
# 15114  [('Rated 5.0', 'RATED\n  Awesome would be an u...        []
# 36363  [('Rated 5.0', 'RATED\n  Awesome would be an u...        []
# 32048  [('Rated 5.0', 'RATED\n  It is just Bukhara wi...        []
# 33105  [('Rated 3.0', "RATED\n  We had visited this p...        []
# 33520  [('Rated 3.0', "RATED\n  We had visited this p...        []
# ...                                                  ...       ...
# 33562  [('Rated 3.0', 'RATED\n  Went there for buffet...        []
# 31079  [('Rated 2.0', "RATED\n  I was here last Sunda...        []
# 3985   [('Rated 4.0', 'RATED\n  Had breakfast at the ...        []
# 10421  [('Rated 5.0', 'RATED\n  Such an elegant place...        []
# 30707  [('Rated 5.0', 'RATED\n  Such an elegant place...        []
#
#                      type              city
# 15114            Dine-out       Indiranagar
# 36363            Dine-out  Old Airport Road
# 32048            Dine-out      Malleshwaram
# 33105            Dine-out      Marathahalli
# 33520  Drinks & nightlife      Marathahalli
# ...                   ...               ...
# 33562              Buffet           MG Road
# 31079            Dine-out      Lavelle Road
# 3985               Buffet      Brigade Road
# 10421            Dine-out     Church Street
# 30707            Dine-out      Lavelle Road
#
# [79 rows x 13 columns]

# %%
x1=df[df.cost>3000] 
x1=x1.sort_values(ascending=False,by="cost")
x1=x1.location.value_counts(ascending=False)
print(x1)
# Out:
# location
# Residency Road      38
# Old Airport Road    10
# Richmond Road       10
# Sankey Road          7
# Lavelle Road         4
# Race Course Road     4
# Vasanth Nagar        3
# Marathahalli         2
# Seshadripuram        1
# Name: count, dtype: int64

# %% [markdown]
# # Where are most of the expensive Restaurants are located ?

# %%
#df[df.cost>3000].sort_values(ascending=False,by="cost").location.value_counts().iplot(kind="bar")

# Get the value counts of locations for expensive restaurants
location_counts = df[df.cost > 3000].sort_values(by="cost", ascending=False).location.value_counts()

# Create a bar chart using Plotly Express
fig = px.bar(
    x=location_counts.index,  # Location names
    y=location_counts.values,  # Count values
    labels={'x': 'Location', 'y': 'Count'},
    title='Expensive Restaurants by Location'
)

# Display the figure
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="5afce0f6-9119-4875-915b-489c35c64b8a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5afce0f6-9119-4875-915b-489c35c64b8a")) {                    Plotly.newPlot(                        "5afce0f6-9119-4875-915b-489c35c64b8a",                        [{"hovertemplate":"Location=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Residency Road","Old Airport Road","Richmond Road","Sankey Road","Lavelle Road","Race Course Road","Vasanth Nagar","Marathahalli","Seshadripuram"],"xaxis":"x","y":{"dtype":"i1","bdata":"JgoKBwQEAwIB"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl ...

# %% [markdown]
#  Majority of Expensive Restaurants are located in Residency Road

# %%
# Get the value counts of restaurant types for expensive restaurants
rest_type_counts = df[df.cost > 3000].rest_type.value_counts()

# Create a bar chart using Plotly Express
fig = px.bar(
    x=rest_type_counts.index,  # Restaurant types
    y=rest_type_counts.values,  # Count values
    labels={'x': 'Restaurant Type', 'y': 'Count'},
    title='Expensive Restaurants by Type'
)

# Display the figure
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="3cabce93-515a-4932-bf30-867da3cfc296" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3cabce93-515a-4932-bf30-867da3cfc296")) {                    Plotly.newPlot(                        "3cabce93-515a-4932-bf30-867da3cfc296",                        [{"hovertemplate":"Restaurant Type=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Fine Dining","Fine Dining, Bar","Lounge"],"xaxis":"x","y":{"dtype":"i1","bdata":"OBUC"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter ...

# %% [markdown]
#  Majority of Expensive Restaurants are Fine Dining.

# %% [markdown]
# # Ratings by Type of Restaurants

# %%
# Create the crosstab
rate_type = pd.crosstab(df['rate'], df['type'])

# Create a stacked bar chart using Plotly Express
fig = px.bar(
    rate_type,
    barmode='stack',
    labels={'index': 'Rating', 'value': 'Count', 'variable': 'Restaurant Type'},
    title='Restaurant Ratings by Type'
)

# Display the figure
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="a6a7257a-f7af-4ddc-ad81-36678d37d159" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a6a7257a-f7af-4ddc-ad81-36678d37d159")) {                    Plotly.newPlot(                        "a6a7257a-f7af-4ddc-ad81-36678d37d159",                        [{"hovertemplate":"type=Buffet\u003cbr\u003erate=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Buffet","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Buffet","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"zczMzMzM\"},"xaxis":"x","y":{"dtype":"i1","bdata":"AAAAAAUAAQMEEAgVDQIPBRwNJVpbVUhMY0kqDRUFCQ=="},"yaxis":"y","type":"bar"},{"hovertemplate":"type=Cafes\u003cbr\u003erate=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cafes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Cafes","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"zczMzMzM\"},"xaxis":"x","y":{"dtype":"i2","bdata":"AAAAAAAAAAABAAIAAgAKAAkAEgAcABIAFgApACcAJQAmAG4AfgCaAHQAhgC9AJYAdwBIACkAFwAMAAAAAAA="},"yaxis":"y","type":"bar"},{"hovertemplate":"type=Delivery\u003cbr\u003erate=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delivery","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Delivery","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"zczMzMzM\"},"xaxis":"x","y":{"dtype":"i2","bdata":"AAABABAACwAWAB8ANQCOAIgAKgGcASwCawPiA7AEUgXTBQIHBAiwB9gH8AUWBVcDXgJ\u002fAcoASwAbABEAEgA="},"yaxis":"y","type":"bar"},{"hovertemplate":"type=Desserts\u003cbr\u003erate=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Desserts","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Desserts","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"zczMzMzM\"},"xaxis":"x","y":{"dtype":"i2","bdata":"AAAAAAAAAAAAAAEAAQAFAAkADwA5ABgANQBrAH8AqwDYAL0A9ADsAB8BCwHsAKgAdQBGADcAGgAKAAsABwA="},"yaxis":"y","type":"bar"},{"hovertemplate":"type=Dine-out\u003cbr\u003erate=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Dine-out","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Dine-out","orientation":"v","showlegend":true,"tex ...

# %%
rate_type
# Out:
# type  Buffet  Cafes  Delivery  Desserts  Dine-out  Drinks & nightlife  \
# rate
# 1.8        0      0         0         0         5                   0
# 2.0        0      0         1         0         6                   4
# 2.1        0      0        16         0         8                   0
# 2.2        0      0        11         0        15                   0
# 2.3        5      1        22         0        23                   0
# 2.4        0      2        31         1        28                   2
# 2.5        1      2        53         1        41                   1
# 2.6        3     10       142         5        83                   5
# 2.7        4      9       136         9       136                   6
# 2.8       16     18       298        15       228                   4
# 2.9        8     28       412        57       284                   8
# 3.0       21     18       556        24       344                  17
# 3.1       13     22       875        53       573                   8
# 3.2        2     41       994       107       682                   8
# 3.3       15     39      1200       127       851                  18
# 3.4        5     37      1362       171       842                  15
# 3.5       28     38      1491       216       936                  34
# 3.6       13    110      1794       189      1132                  28
# 3.7       37    126      2052       244      1261                  58
# 3.8       90    154      1968       236      1272                  63
# 3.9       91    116      2008       287      1281                 105
# 4.0       85    134      1520       267       988                  98
# 4.1       72    189      1302       236       936                 110
# 4.2       76    150       855       168       711                 113
# 4.3       99    119       606       117       571                 111
# 4.4       73     72       383        70       383                 114
# 4.5       42     41       202        55       218                  60
# 4.6       13     23        75        26       115                  29
# 4.7       21     12        27        10        65                  18
# 4.8        5      0        17        11        21                   6
# 4.9        9      0        18         7        16                   2
#
# type  Pubs and bars
# rate
# 1.8               0
# 2.0               0
# 2.1               0
# 2.2               0
# 2.3               0
# 2.4               2
# 2.5               1
# 2.6               1
# 2.7               3
# 2.8               1
# 2.9               4
# 3.0              10
# 3.1               6
# 3.2               6
# 3.3              22
# 3.4              12
# 3.5              19
# 3.6              17
# 3.7              26
# 3.8              33
# 3.9              66
# 4.0              52
# 4.1              80
# 4.2              81
# 4.3              59
# 4.4              51
# 4.5              38
# 4.6              19
# 4.7              14
# 4.8               6
# 4.9               3

# %%
df.sort_values(ascending=False,by="votes").head(10)
# Out:
#                               name online_order book_table  rate  votes  \
# 39990  Byg Brewski Brewing Company          Yes        Yes   4.9  16832
# 39315  Byg Brewski Brewing Company          Yes        Yes   4.9  16832
# 39640  Byg Brewski Brewing Company          Yes        Yes   4.9  16832
# 3935   Byg Brewski Brewing Company          Yes        Yes   4.9  16345
# 3824   Byg Brewski Brewing Company          Yes        Yes   4.9  16345
# 3171   Byg Brewski Brewing Company          Yes        Yes   4.9  16345
# 15211                         Toit           No         No   4.7  14956
# 14689                         Toit           No         No   4.7  14956
# 29066                     Truffles           No         No   4.7  14726
# 28615                     Truffles           No         No   4.7  14723
#
#                     location            rest_type  \
# 39990          Sarjapur Road         Microbrewery
# 39315          Sarjapur Road         Microbrewery
# 39640          Sarjapur Road         Microbrewery
# 3935           Sarjapur Road         Microbrewery
# 3824           Sarjapur Road         Microbrewery
# 3171           Sarjapur Road         Microbrewery
# 15211            Indiranagar         Microbrewery
# 14689            Indiranagar         Microbrewery
# 29066  Koramangala 5th Block  Cafe, Casual Dining
# 28615  Koramangala 5th Block  Cafe, Casual Dining
#
#                                                 cuisines    cost  \
# 39990  Continental, North Indian, Italian, South Indi...  1600.0
# 39315  Continental, North Indian, Italian, South Indi...  1600.0
# 39640  Continental, North Indian, Italian, South Indi...  1600.0
# 3935   Continental, North Indian, Italian, South Indi...  1600.0
# 3824   Continental, North Indian, Italian, South Indi...  1600.0
# 3171   Continental, North Indian, Italian, South Indi...  1600.0
# 15211                           Italian, American, Pizza  1500.0
# 14689                           Italian, American, Pizza  1500.0
# 29066                      Cafe, American, Burger, Steak   900.0
# 28615                      Cafe, American, Burger, Steak   900.0
#
#                                             reviews_list  \
# 39990  [('Rated 4.0', 'RATED\n  Visiting a microbrewe...
# 39315  [('Rated 5.0', "RATED\n  This is an absolute g...
# 39640  [('Rated 4.0', 'RATED\n  Visiting a microbrewe...
# 3935   [('Rated 5.0', 'RATED\n  I have been to this p...
# 3824   [('Rated 5.0', 'RATED\n  I have been to this p...
# 3171   [('Rated 5.0', 'RATED\n  I have been to this p...
# 15211  [('Rated 4.0', "RATED\n  The crowd keeps flowi...
# 14689  [('Rated 4.0', "RATED\n  The crowd keeps flowi...
# 29066  [('Rated 3.0', "RATED\n  Not bad but the burge...
# 28615  [('Rated 3.0', "RATED\n  Not bad but the burge...
#
#                                                menu_item                type  \
# 39990                                                 []  Drinks & nightlife
# 39315                                                 []            Delivery
# 39640                                                 []            Dine-out
# 3935   ['Creamy Mushroom and Truffle Soup', 'Kung Pao...  Drinks & nightlife
# 3824   ['Creamy Mushroom and Truffle Soup', 'Kung Pao...            Dine-out
# 3171                                                  []            Delivery
# 15211                                                 []  Drinks & nightlife
# 14689                                                 []            Dine-out
# 29066                                                 []            Dine-out
# 28615                                                 []            Delivery
#
#                         city
# 39990          Sarjapur Road
# 39315          Sarjapur Road
# 39640          Sarjapur Road
# 3935               Bellandur
# 3824               Bellandur
# 3171               Bellandur
# 15211            Indiranagar
# 14689            Indiranagar
# 29066  Koramangala 7th Block
# 28615  Koramangala 7th Block

# %% [markdown]
# # Restaurants per location

# %%
# Get the top 20 locations by count
top_locations = df["location"].value_counts().head(20)

# Create a bar chart using Plotly Express
fig = px.bar(
    x=top_locations.index,  # Location names
    y=top_locations.values,  # Count values
    labels={'x': 'Location', 'y': 'Count'},
    title='Top 20 Restaurant Locations'
)

# Display the figure
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="8a6265f8-dda6-4e7c-9c29-74da3b9da461" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8a6265f8-dda6-4e7c-9c29-74da3b9da461")) {                    Plotly.newPlot(                        "8a6265f8-dda6-4e7c-9c29-74da3b9da461",                        [{"hovertemplate":"Location=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["BTM","Koramangala 5th Block","HSR","Indiranagar","JP Nagar","Jayanagar","Whitefield","Marathahalli","Bannerghatta Road","Koramangala 7th Block","Brigade Road","Koramangala 6th Block","Bellandur","Sarjapur Road","Koramangala 1st Block","Ulsoor","Koramangala 4th Block","Electronic City","MG Road","Banashankari"],"xaxis":"x","y":{"dtype":"i2","bdata":"IQ\u002f4CMkHCAeuBmIGIAaCBcgEHwQcBBwE5ANWA1MDTgNJA0ADGQPoAg=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks": ...

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x="rate",y='cost',hue='online_order',data=df,style="book_table")
plt.show()

# %% [markdown]
# # Best Economical Restaurants

# %%
df[(df["cost"]<=100) & (df["rate"]>=4)].sort_values(by=["rate"],ascending=False)
# Out:
#                                      name online_order book_table  rate  \
# 2666                 Brahmin's Coffee Bar           No         No   4.8
# 547                          Taaza Thindi           No         No   4.7
# 16959  Sri Laxmi Venkateshwara Coffee Bar           No         No   4.4
# 556    Sri Laxmi Venkateshwara Coffee Bar           No         No   4.4
# 2851   Sri Laxmi Venkateshwara Coffee Bar           No         No   4.4
# ...                                   ...          ...        ...   ...
# 23371                 Hari Super Sandwich          Yes         No   4.0
# 21114                 Hari Super Sandwich          Yes         No   4.0
# 21018                        Shiv Shakthi          Yes         No   4.0
# 2023                           SL Vadapav          Yes         No   4.0
# 39527                        Mumbai Kulfi          Yes         No   4.0
#
#        votes      location       rest_type                   cuisines   cost  \
# 2666    2679  Basavanagudi     Quick Bites               South Indian  100.0
# 547      651  Banashankari     Quick Bites               South Indian  100.0
# 16959    344  Banashankari     Quick Bites               South Indian  100.0
# 556      343  Banashankari     Quick Bites               South Indian  100.0
# 2851     343  Banashankari     Quick Bites               South Indian  100.0
# ...      ...           ...             ...                        ...    ...
# 23371     18           BTM     Quick Bites        Sandwich, Fast Food  100.0
# 21114     16           BTM     Quick Bites        Sandwich, Fast Food  100.0
# 21018    176           HSR     Quick Bites  Street Food, North Indian  100.0
# 2023      78     Jayanagar     Quick Bites              Maharashtrian  100.0
# 39527     92           HSR  Dessert Parlor                  Ice Cream  100.0
#
#                                             reviews_list  \
# 2666   [('Rated 5.0', "RATED\n  Very soft idly, soft ...
# 547    [('Rated 5.0', 'RATED\n  One of the cleanest s...
# 16959  [('Rated 4.0', "RATED\n  For Early morning bre...
# 556    [('Rated 4.0', "RATED\n  For Early morning bre...
# 2851   [('Rated 4.0', "RATED\n  For Early morning bre...
# ...                                                  ...
# 23371  [('Rated 3.0', 'RATED\n  A different way of se...
# 21114  [('Rated 3.0', 'RATED\n  A different way of se...
# 21018  [('Rated 4.0', 'RATED\n  After along time ..th...
# 2023   [('Rated 4.0', 'RATED\n  Zomato home delivery ...
# 39527  [('Rated 4.0', 'RATED\n  went here on sunday e...
#
#                                                menu_item      type  \
# 2666                                                  []  Dine-out
# 547                                                   []  Dine-out
# 16959                                                 []  Dine-out
# 556                                                   []  Dine-out
# 2851                                                  []  Dine-out
# ...                                                  ...       ...
# 23371  ['Veg Pizza [6 inches]', 'Paneer Pizza [6 inch...  Delivery
# 21114  ['Veg Pizza [6 inches]', 'Capsicum Pizza [6 in...  Delivery
# 21018  ['Jalebi [100 grams]', 'Samosa [1 Piece]', 'Da...  Delivery
# 2023                                                  []  Delivery
# 39527                                                 []  Delivery
#
#                         city
# 2666            Basavanagudi
# 547             Banashankari
# 16959              Jayanagar
# 556             Banashankari
# 2851            Basavanagudi
# ...                      ...
# 23371  Koramangala 5th Block
# 21114  Koramangala 4th Block
# 21018  Koramangala 4th Block
# 2023            Basavanagudi
# 39527          Sarjapur Road
#
# [83 rows x 13 columns]

# %% [markdown]
# # Where are most of the best chepest  Restaurants are located ?

# %%
# Filter for affordable restaurants with high ratings and get location counts
affordable_high_rated = df[(df["cost"] <= 100) & (df["rate"] >= 4)].sort_values(by=["rate"], ascending=False)
location_counts = affordable_high_rated.location.value_counts()

# Create a bar chart using Plotly Express
fig = px.bar(
    x=location_counts.index,  # Location names
    y=location_counts.values,  # Count values
    labels={'x': 'Location', 'y': 'Count'},
    title='Locations of Affordable Restaurants with High Ratings'
)

# Display the figure
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="1937d409-9a30-412e-9b09-5d9997b7cf71" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1937d409-9a30-412e-9b09-5d9997b7cf71")) {                    Plotly.newPlot(                        "1937d409-9a30-412e-9b09-5d9997b7cf71",                        [{"hovertemplate":"Location=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Basavanagudi","Jayanagar","Malleshwaram","HSR","Banashankari","BTM","Frazer Town","JP Nagar","Kalyan Nagar","Bellandur","Jeevan Bhima Nagar","Vijay Nagar","Sanjay Nagar","Koramangala 6th Block"],"xaxis":"x","y":{"dtype":"i1","bdata":"FRQIBwYFBAMCAgIBAQE="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","s ...

# %% [markdown]
# Best Cheap Restaurants are located at Basavangudi,jayanagar,malleshwaram & HSR

# %%
df["cost"].mean()
# Out:
# np.float64(603.9612380536555)

# %% [markdown]
# # Best Average cost Restaurants

# %%
df[(df["cost"]<=df["cost"].mean()) & (df["rate"]>=4) ].sort_values(by=["rate"],ascending=False)
# Out:
#                          name online_order book_table  rate  votes  \
# 38305  Belgian Waffle Factory          Yes         No   4.9   1749
# 8183   Belgian Waffle Factory          Yes         No   4.9    201
# 4658   Belgian Waffle Factory          Yes         No   4.9   1746
# 34279  Belgian Waffle Factory          Yes         No   4.9   1750
# 11634  Belgian Waffle Factory          Yes         No   4.9   1743
# ...                       ...          ...        ...   ...    ...
# 27673          Punjabi Nawabi          Yes         No   4.0    109
# 13309               Warm Oven          Yes         No   4.0    153
# 27670                  Faasos          Yes         No   4.0    461
# 13310            Mumbai Kulfi          Yes         No   4.0     92
# 29331                Momo Hut          Yes         No   4.0    685
#
#                     location       rest_type  \
# 38305           Brigade Road  Dessert Parlor
# 8183   Koramangala 5th Block  Dessert Parlor
# 4658            Brigade Road  Dessert Parlor
# 34279           Brigade Road  Dessert Parlor
# 11634           Brigade Road  Dessert Parlor
# ...                      ...             ...
# 27673  Koramangala 1st Block   Casual Dining
# 13309                    HSR          Bakery
# 27670  Koramangala 8th Block     Quick Bites
# 13310                    HSR  Dessert Parlor
# 29331  Koramangala 5th Block     Quick Bites
#
#                                cuisines   cost  \
# 38305                          Desserts  400.0
# 8183                           Desserts  400.0
# 4658                           Desserts  400.0
# 34279                          Desserts  400.0
# 11634                          Desserts  400.0
# ...                                 ...    ...
# 27673                      North Indian  500.0
# 13309                  Bakery, Desserts  500.0
# 27670  North Indian, Biryani, Fast Food  500.0
# 13310                         Ice Cream  100.0
# 29331           Chinese, Tibetan, Momos  250.0
#
#                                             reviews_list  \
# 38305  [('Rated 4.0', "RATED\n  Looks like there's a ...
# 8183   [('Rated 4.0', "RATED\n  FYI, I have no photos...
# 4658   [('Rated 3.0', "RATED\n  Waffles are totally w...
# 34279  [('Rated 4.0', "RATED\n  Looks like there's a ...
# 11634  [('Rated 3.0', "RATED\n  Waffles are totally w...
# ...                                                  ...
# 27673  [('Rated 5.0', 'RATED\n  Best option for North...
# 13309  [('Rated 3.0', "RATED\n  3/5 only because of d...
# 27670  [('Rated 4.0', 'RATED\n  Ordered food for deli...
# 13310  [('Rated 4.0', 'RATED\n  went here on sunday e...
# 29331  [('Rated 5.0', 'RATED\n  i have been going to ...
#
#                                                menu_item      type  \
# 38305                                                 []  Desserts
# 8183                                                  []  Desserts
# 4658                                                  []  Desserts
# 34279  ['The Red Wonder Waffle [Bubble]', 'Bubble Kit...  Desserts
# 11634                                                 []  Delivery
# ...                                                  ...       ...
# 27673  ['Ambarsari Kulcha Combo', 'Chur Chur Naan Com...  Delivery
# 13309                                                 []  Desserts
# 27670  ['Chicken Biryani', 'Paneer Biryani', 'Barbequ...  Delivery
# 13310                                                 []  Desserts
# 29331  ['Steamed Veg Momos', 'Steamed Chicken Momos',...  Dine-out
#
#                         city
# 38305         Residency Road
# 8183                     BTM
# 4658            Brigade Road
# 34279                MG Road
# 11634            Frazer Town
# ...                      ...
# 27673  Koramangala 7th Block
# 13309                    HSR
# 27670  Koramangala 7th Block
# 13310                    HSR
# 29331  Koramangala 7th Block
#
# [5053 rows x 13 columns]

# %%
df["cost"].mean()
# Out:
# np.float64(603.9612380536555)

# %% [markdown]
# # Popular cuisines in Bangalore

# %%
# Get the top 10 cuisines by count
top_cuisines = df.cuisines.value_counts().sort_values(ascending=False).head(10)

# Create a bar chart using Plotly Express
fig = px.bar(
    x=top_cuisines.index,  # Cuisine names
    y=top_cuisines.values,  # Count values
    labels={'x': 'Cuisine', 'y': 'Count'},
    title='Top 10 Cuisines'
)

# Display the figure
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="6514983a-ebeb-4d9a-8423-20f9befab483" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6514983a-ebeb-4d9a-8423-20f9befab483")) {                    Plotly.newPlot(                        "6514983a-ebeb-4d9a-8423-20f9befab483",                        [{"hovertemplate":"Cuisine=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["North Indian","North Indian, Chinese","South Indian","Cafe","Bakery, Desserts","Biryani","South Indian, North Indian, Chinese","Desserts","Fast Food","Chinese"],"xaxis":"x","y":{"dtype":"i2","bdata":"OwidB88EbAJlAlgCMQIhAgACmQE="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"t ...

# %% [markdown]
#  North indian ,Chinese & South indian are some of the popular cuisines in Bangalore

# %% [markdown]
# # Average Cost by Location

# %%
resbyloc=df.groupby("location")

# %%
#resbyloc.mean()

# %%
#resbyloc.mean().sort_values(by="cost").iplot(kind="bar",barmode="stack")

# %% [markdown]
# # Finding best Restaurants by Cost & Location

# %%
# print(" Cost for 2 :")
res_cost=float(input(""))
print("Location : ")
res_loc=input("")
def top_rest(res_cost,res_loc):
    x=df[(df["cost"]<=res_cost) & (df["rate"]>=4) & (df["location"]==res_loc) ].sort_values(by=["rate"],ascending=False)
    return x
top_rest(res_cost,res_loc)
